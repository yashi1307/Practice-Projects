# %% [markdown]
# # Project-3 : World Happiness Report

# %% [markdown]
# **Project Description : The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.**

# %% [markdown]
# **What is Dystopia?**
#
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.
#
# **What are the residuals?**
#
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average life evaluations. These residuals have an average value of approximately zero over the whole set of countries.
#
# **What do the columns succeeding the Happiness Score(like Family, Generosity, etc.) describe?**
#
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.
# The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country.
#
# The Dystopia Residual is already provided in the dataset.
#
# If you add all these factors up, you get the happiness score so it might be un-reliable to model them to predict Happiness Scores.

# %% [markdown]
# **To Predict** : **"Happiness score"** considering all the other factors mentioned in the dataset.**

# %%
# Let's start with importing Necessary Libraries:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing  Dataset :

data = pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")

data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
# To Display top 5 Rows:

data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
# To Display all Columns:

data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %% [markdown]
# **There are 158 rows and 12 columns , where some of them are of object datatype , int datatype and float datatype.**

# %%
data.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# **Here , Country and Region are of object datatype , as they have string values. Happiness Rank is of int datatype , and all other are of Float Datatype.**

# %%
# Checking for null values:

data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# **There are no null values present , let's go ahead.**

# %%
# Converting Happiness Rank into float Datatype for better prediction:

data['Happiness Rank']= data['Happiness Rank'].astype(float)

# %%
# Let's Verify , If this column is converted to float datatype or not:

data.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                   float64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# **AS there are two type of data , Nominal data and Continuous data . Let's create individual dataframe for both type of data , So it'll be easy to understand.**

# %%
# Dataframe of Nominal Data :

data_nominal = data[['Country','Region']].copy()
data_nominal.columns
# Out:
# Index(['Country', 'Region'], dtype='object')

# %%
# Dataframe of Continuous Data:

data_cont = data[['Happiness Rank','Happiness Score','Standard Error','Economy (GDP per Capita)', 'Family','Health (Life Expectancy)','Freedom',
                 'Trust (Government Corruption)','Generosity','Dystopia Residual']].copy()

data_cont.columns
# Out:
# Index(['Happiness Rank', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # Data Visualization :

# %%
sns.distplot(data_cont['Happiness Rank'],kde=True)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(data_cont['Happiness Score'],kde=True)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(data_cont['Standard Error'],kde=True)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(data_cont['Economy (GDP per Capita)'],kde=True)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(data_cont['Family'],kde=True)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(data_cont['Health (Life Expectancy)'],kde=True)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(data_cont['Freedom'],kde=True)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(data_cont['Trust (Government Corruption)'],kde=True)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(data_cont['Generosity'],kde=True)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(data_cont['Dystopia Residual'],kde=True)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# **As system only understand numeric values , and we have two columns which have string values. So , We have to transform these values to numerics using Ordinal Encoder.**
#
# **Ordinal Encoder** is a technique which is used to tranform the string data to numeric data or simply convert to that type which is easy to understand for system.

# %%
# let's use Ordinal Encoder for those columns which have object datatype basically :

# Importing OrdinalEncoder:

from sklearn.preprocessing import OrdinalEncoder

# Let's initialize OrdinalEncoder:

Encoder = OrdinalEncoder()

# %%
for i in data.columns:
    if data[i].dtypes=='object':
        data[i] = Encoder.fit_transform(data[i].values.reshape(-1,1))

# %%
data
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0             1.0            7.587         0.03411
# 1       58.0     9.0             2.0            7.561         0.04884
# 2       37.0     9.0             3.0            7.527         0.03328
# 3      105.0     9.0             4.0            7.522         0.03880
# 4       24.0     5.0             5.0            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0           154.0            3.465         0.03464
# 154     13.0     8.0           155.0            3.340         0.03656
# 155    136.0     4.0           156.0            3.006         0.05015
# 156     21.0     8.0           157.0            2.905         0.08658
# 157    141.0     8.0           158.0            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# 155                        0.18906     0.47179            0.32858
# 156                        0.10062     0.19727            1.83302
# 157                        0.10731     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
# To Display complete Statistics of Dataset:

data.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# 50%          0.043940                  0.910245    1.029510
# 75%          0.052300                  1.158448    1.214405
# max          0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual
# count  158.000000         158.000000
# mean     0.237296           2.098977
# std      0.126685           0.553550
# min      0.000000           0.328580
# 25%      0.150553           1.759410
# 50%      0.216130           2.095415
# 75%      0.309883           2.462415
# max      0.795880           3.602140

# %%
# Let's have visualiation of Statistics of data:

plt.figure(figsize=(12,10))
sns.heatmap(data.describe(),annot= True, linewidth=0.1, linecolor="Yellow", fmt="0.3f")
# Out:
# <AxesSubplot:>

# %%
#Let's check for Correlation with label:

data.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# Country                               0.083380        0.033879
# Region                               -0.176791       -0.022600
# Happiness Rank                       -0.992105        0.158516
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Country                                        0.037808  0.159416
# Region                                        -0.260139 -0.168533
# Happiness Rank                                -0.785267 -0.733644
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# Health (Life Expectancy)                       0.816478  0.531104
# Freedom                                        0.370300  0.441518
# Trust (Government Corruption)                  0.307885  0.205605
# Generosity                                    -0.010465  0.087513
# Dystopia Residual                              0.040059  0.148117
#
#                                Health (Life Expectancy)   Freedom  \
# Country                                        0.037829  0.085684
# Region                                        -0.357508  0.092567
# Happiness Rank                                -0.735613 -0.556886
# Happiness Score                                0.724200  0.568211
# Standard Error                                -0.310287 -0.129773
# Economy (GDP per Capita)                       0.816478  0.370300
# Family                                         0.531104  0.441518
# Health (Life Expectancy)                       1.000000  0.360477
# Freedom                                        0.360477  1.000000
# Trust (Government Corruption)                  0.248335  0.493524
# Generosity                                     0.108335  0.373916
# Dystopia Residual                              0.018979  0.062783
#
#                                Trust (Government Corruption)  Generosity  \
# Country                                             0.088155    0.118085
# Region                                              0.165040    0.273557
# Happiness Rank                                     -0.372315   -0.160142
# Happiness Score                                     0.395199    0.180319
# Standard Error                                     -0.178325   -0.088439
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000
# Dystopia Residual                                  -0.033105   -0.101301
#
#                                Dystopia Residual
# Country                                -0.019778
# Region                                 -0.057276
# Happiness Rank                         -0.521999
# Happiness Score                         0.530474
# Standard Error                          0.083981
# Economy (GDP per Capita)                0.040059
# Family                                  0.148117
# Health (Life Expectancy)                0.018979
# Freedom                                 0.062783
# Trust (Government Corruption)          -0.033105
# Generosity                             -0.101301
# Dystopia Residual                       1.000000

# %%
# Let's Visualize above data:

plt.figure(figsize=(12,10))
sns.heatmap(data.corr() ,annot = True ,linecolor = 'Yellow' ,linewidth=0.1,fmt="0.2f", annot_kws={"size": 16})
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Here , Happiness Score and Economy (GDP per Capita) are seems to be Correlated . So we can drop one of them.**

# %%
data.drop(columns='Happiness Score',axis=1)
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0      135.0     9.0             1.0         0.03411
# 1       58.0     9.0             2.0         0.04884
# 2       37.0     9.0             3.0         0.03328
# 3      105.0     9.0             4.0         0.03880
# 4       24.0     5.0             5.0         0.03553
# ..       ...     ...             ...             ...
# 153    118.0     8.0           154.0         0.03464
# 154     13.0     8.0           155.0         0.03656
# 155    136.0     4.0           156.0         0.05015
# 156     21.0     8.0           157.0         0.08658
# 157    141.0     8.0           158.0         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# 155                        0.18906     0.47179            0.32858
# 156                        0.10062     0.19727            1.83302
# 157                        0.10731     0.16681            1.56726
#
# [158 rows x 11 columns]

# %% [markdown]
# **As we have seen in Distribution plots of all features , there's some skewness . Let's check for skewness.**

# %%
data.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# **As per report of skewness , Standard error is has more skewness  , so let's drop this column.**

# %%
data.drop(['Standard Error'],axis=1, inplace=True )

# %% [markdown]
# # Removing Multicollinearity

# %%
def  cal_vif(x):
    vif =pd.DataFrame()
    vif['variables']=x.columns
    vif['VIF factor']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif)

# %% [markdown]
# # Outliers removal with Scipy

# %%
import scipy
from scipy.stats import zscore

z= np.abs(zscore(data))
z
# Out:
#       Country    Region  Happiness Rank  Happiness Score  \
# 0    1.238770  1.300256        1.721000         1.937360
# 1    0.449465  1.300256        1.699075         1.914581
# 2    0.909893  1.300256        1.677149         1.884792
# 3    0.581016  1.300256        1.655224         1.880411
# 4    1.194920  0.040302        1.633299         1.797179
# ..        ...       ...             ...              ...
# 153  0.866043  0.965117        1.633576         1.674055
# 154  1.436096  0.965117        1.655501         1.783571
# 155  1.260695  0.375441        1.677427         2.076199
# 156  1.260695  0.965117        1.699352         2.164688
# 157  1.370321  0.965117        1.721277         2.222513
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.369621  1.320281                  1.263408  1.577438
# 1                    1.135226  1.514458                  1.289434  1.332456
# 2                    1.192861  1.361054                  0.992229  1.469659
# 3                    1.525130  1.251922                  1.035145  1.605131
# 4                    1.194876  1.221204                  1.118054  1.360416
# ..                        ...       ...                       ...       ...
# 153                  1.552987  0.800520                  0.818610  1.087740
# 154                  1.392303  2.346860                  1.263362  0.372033
# 155                  0.455245  1.901086                  0.372199  1.809238
# 156                  2.067566  2.118467                  1.649648  2.064472
# 157                  1.586334  3.134725                  1.404129  0.426621
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                         2.309652    0.471040           0.758258
# 1                         0.016480    1.575856           1.092857
# 2                         2.842774    0.824293           0.712335
# 3                         1.852081    0.868638           0.663893
# 4                         1.555725    1.748563           0.639337
# ..                             ...         ...                ...
# 153                       3.413922    0.087228           2.588925
# 154                       0.529210    0.433117           0.843967
# 155                       0.381419    1.856891           3.208430
# 156                       0.357715    0.316950           0.481985
# 157                       0.301803    0.558153           0.963612
#
# [158 rows x 11 columns]

# %%
data.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27, 128, 147, 153, 155, 157], dtype=int64), array([ 8,  9,  5,  8, 10,  5], dtype=int64))

# %%
z
# Out:
#       Country    Region  Happiness Rank  Happiness Score  \
# 0    1.238770  1.300256        1.721000         1.937360
# 1    0.449465  1.300256        1.699075         1.914581
# 2    0.909893  1.300256        1.677149         1.884792
# 3    0.581016  1.300256        1.655224         1.880411
# 4    1.194920  0.040302        1.633299         1.797179
# ..        ...       ...             ...              ...
# 153  0.866043  0.965117        1.633576         1.674055
# 154  1.436096  0.965117        1.655501         1.783571
# 155  1.260695  0.375441        1.677427         2.076199
# 156  1.260695  0.965117        1.699352         2.164688
# 157  1.370321  0.965117        1.721277         2.222513
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.369621  1.320281                  1.263408  1.577438
# 1                    1.135226  1.514458                  1.289434  1.332456
# 2                    1.192861  1.361054                  0.992229  1.469659
# 3                    1.525130  1.251922                  1.035145  1.605131
# 4                    1.194876  1.221204                  1.118054  1.360416
# ..                        ...       ...                       ...       ...
# 153                  1.552987  0.800520                  0.818610  1.087740
# 154                  1.392303  2.346860                  1.263362  0.372033
# 155                  0.455245  1.901086                  0.372199  1.809238
# 156                  2.067566  2.118467                  1.649648  2.064472
# 157                  1.586334  3.134725                  1.404129  0.426621
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                         2.309652    0.471040           0.758258
# 1                         0.016480    1.575856           1.092857
# 2                         2.842774    0.824293           0.712335
# 3                         1.852081    0.868638           0.663893
# 4                         1.555725    1.748563           0.639337
# ..                             ...         ...                ...
# 153                       3.413922    0.087228           2.588925
# 154                       0.529210    0.433117           0.843967
# 155                       0.381419    1.856891           3.208430
# 156                       0.357715    0.316950           0.481985
# 157                       0.301803    0.558153           0.963612
#
# [158 rows x 11 columns]

# %%
z.iloc[40]
# Out:
# Country                          1.392246
# Region                           0.710580
# Happiness Rank                   0.843987
# Happiness Score                  0.694129
# Economy (GDP per Capita)         0.910039
# Family                           0.708987
# Health (Life Expectancy)         0.062646
# Freedom                          0.866924
# Trust (Government Corruption)    1.103367
# Generosity                       0.642559
# Dystopia Residual                0.307801
# Name: 40, dtype: float64

# %%
data_new= data[(z<3).all(axis=1)]

# %%
print('old_dataframe',data.shape)
print('new_dataframe', data_new.shape)
print('total_dropped_rows', data.shape[0]-data_new.shape[0])
# Out:
# old_dataframe (158, 11)
# new_dataframe (152, 11)
# total_dropped_rows 6

# %%
loss_percent=((158-149)/158)*100
loss_percent
# Out:
# 5.69620253164557

# %%
data_new
# Out:
#      Country  Region  Happiness Rank  Happiness Score  \
# 0      135.0     9.0             1.0            7.587
# 1       58.0     9.0             2.0            7.561
# 2       37.0     9.0             3.0            7.527
# 3      105.0     9.0             4.0            7.522
# 4       24.0     5.0             5.0            7.427
# ..       ...     ...             ...              ...
# 150     66.0     8.0           151.0            3.655
# 151     20.0     8.0           152.0            3.587
# 152      0.0     7.0           153.0            3.575
# 154     13.0     8.0           155.0            3.340
# 156     21.0     8.0           157.0            2.905
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 150                        0.17922     0.20165            1.41723
# 151                        0.12832     0.21747            1.46494
# 152                        0.09719     0.36510            1.95210
# 154                        0.08010     0.18260            1.63328
# 156                        0.10062     0.19727            1.83302
#
# [152 rows x 11 columns]

# %%
x=data_new.iloc[:,:-1]

# %%
y=data_new.iloc[:,-1]

# %%
# Let's Standardize the data:

from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x=scaler.fit_transform(x)
x
# Out:
# array([[ 1.26399072,  1.30435496, -1.72089178, ...,  1.58646238,
#          2.49273763,  0.54630641],
#        [-0.42691651,  1.30435496, -1.69841   , ...,  1.34083622,
#          0.02815737,  1.7233747 ],
#        [-0.88807303,  1.30435496, -1.67592822, ...,  1.47840022,
#          3.05759077,  0.92266117],
#        ...,
#        [-1.7005869 ,  0.64016081,  1.69633931, ..., -1.29317062,
#         -0.36375986,  1.12269192],
#        [-1.41510905,  0.97225788,  1.74130288, ...,  0.37788823,
#         -0.51508985, -0.41697956],
#        [-1.23943038,  0.97225788,  1.78626644, ..., -2.06502414,
#         -0.3333876 , -0.29321528]])

# %%
# Let's Create Model:

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score

# %%
lr=LinearRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=i, test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print('At random state' , {i} , ':' , 'the training accuracy is : ',{r2_score(y_train,pred_train)})
    print('At random state' , {i} , ':' , 'the testing accuracy is : ',{r2_score(y_test,pred_test)},'\n')
# Out:
# At random state {0} : the training accuracy is :  {0.9999997663749547}
# At random state {0} : the testing accuracy is :  {0.9999994791022829}
#
# At random state {1} : the training accuracy is :  {0.9999997502907543}
# At random state {1} : the testing accuracy is :  {0.999999591282079}
#
# At random state {2} : the training accuracy is :  {0.999999739791925}
# At random state {2} : the testing accuracy is :  {0.9999996148931889}
#
# At random state {3} : the training accuracy is :  {0.9999997193859251}
# At random state {3} : the testing accuracy is :  {0.9999997335906201}
#
# At random state {4} : the training accuracy is :  {0.9999997565384604}
# At random state {4} : the testing accuracy is :  {0.9999994701225404}
#
# At random state {5} : the training accuracy is :  {0.9999997489592334}
# At random state {5} : the testing accuracy is :  {0.9999995804326962}
#
# At random state {6} : the training accuracy is :  {0.9999997844229431}
# At random state {6} : the testing accuracy is :  {0.9999989610308048}
#
# At random state {7} : the training accuracy is :  {0.999999722612357}
# At random state {7} : the testing accuracy is :  {0.9999997199014854}
#
# At random state {8} : the training accuracy is :  {0.9999997171854227}
# At random state {8} : the testing accuracy is :  {0.9999997535552905}
#
# At random state {9} : the training accuracy is :  {0.9999997281660913}
# At random state {9} : the testing accuracy is :  {0.9999997115805722}
#
# At random state {10} : the training accuracy is :  {0.9999997415533513}
# At random state {10} : the testing accuracy is :  {0.9999996507044553}
#
# At random state {11} : the training accuracy is :  {0.9999997273640283}
# At random state {11} : the testing accuracy is :  {0.9999997218870512}
#
# At random state {12} : the training accuracy is :  {0.9999997191184689}
# At random state {12} : the testing accuracy is :  {0.9999997548923137}
#
# At random state {13} : the training accuracy is :  {0.9999997476182786}
# At random state {13} : the testing accuracy is :  {0.9999995943618621}
#
# At random state {14} : the training accuracy is :  {0.9999997478009148}
# At random state {14} : the testing accuracy is :  {0.9999995896059568}
#
# At random state {15} : the training accuracy is :  {0.9999997546034681}
# At random state {15} : the testing accuracy is :  {0.9999994682488611}
#
# At random state {16} : the training accuracy is :  {0.9999997255394188}
# At random state {16} : the testing accuracy is :  {0.9999997188554924}
#
# At random state {17} : the training accuracy is :  {0.999999734399964}
# At random state {17} : the testing accuracy is :  {0.9999996906529479}
#
# At random state {18} : the training accuracy is :  {0.9999997356713168}
# At random state {18} : the testing accuracy is :  {0.9999996826889703}
#
# At random state {19} : the training accuracy is :  {0.999999760055024}
# At random state {19} : the testing accuracy is :  {0.9999995064818249}
#
# At random state {20} : the training accuracy is :  {0.9999997571802542}
# At random state {20} : the testing accuracy is :  {0.9999995354343657}
#
# At random state {21} : the training accuracy is :  {0.999999766697574}
# At random state {21} : the testing accuracy is :  {0.9999994612801517}
#
# At random state {22} : the training accuracy is :  {0.9999997297927288}
# At random state {22} : the testing accuracy is :  {0.9999997090710293}
#
# At random state {23} : the training accuracy is :  {0.9999997400825975}
# At random state {23} : the testing accuracy is :  {0.9999996485797976}
#
# At random state {24} : the training accuracy is :  {0.999999779166131}
# At random state {24} : the testing accuracy is :  {0.9999994035306468}
#
# At random state {25} : the training accuracy is :  {0.999999735762085}
# At random state {25} : the testing accuracy is :  {0.9999996702018719}
#
# At random state {26} : the training accuracy is :  {0.9999997553381295}
# At random state {26} : the testing accuracy is :  {0.9999994975220506}
#
# At random state {27} : the training accuracy is :  {0.9999997203917408}
# At random state {27} : the testing accuracy is :  {0.9999997539028647}
#
# At random state {28} : the training accuracy is :  {0.999999750419754}
# At random state {28} : the testing accuracy is :  {0.9999995972731098}
#
# At random state {29} : the training accuracy is :  {0.9999997454540442}
# At random state {29} : the testing accuracy is :  {0.9999995976824337}
#
# At random state {30} : the training accuracy is :  {0.9999997393085348}
# At random state {30} : the testing accuracy is :  {0.9999996787069934}
#
# At random state {31} : the training accuracy is :  {0.9999997161063346}
# At random state {31} : the testing accuracy is :  {0.9999997420940029}
#
# At random state {32} : the training accuracy is :  {0.9999996942524287}
# At random state {32} : the testing accuracy is :  {0.999999831811528}
#
# At random state {33} : the training accuracy is :  {0.9999997405028278}
# At random state {33} : the testing accuracy is :  {0.9999996287754016}
#
# At random state {34} : the training accuracy is :  {0.9999997592602238}
# At random state {34} : the testing accuracy is :  {0.9999993849116616}
#
# At random state {35} : the training accuracy is :  {0.9999997216432541}
# At random state {35} : the testing accuracy is :  {0.9999997453664099}
#
# At random state {36} : the training accuracy is :  {0.9999997479168372}
# At random state {36} : the testing accuracy is :  {0.9999996214865997}
#
# At random state {37} : the training accuracy is :  {0.9999997291687164}
# At random state {37} : the testing accuracy is :  {0.9999996984974594}
#
# At random state {38} : the training accuracy is :  {0.999999746946597}
# At random state {38} : the testing accuracy is :  {0.9999996348910756}
#
# At random state {39} : the training accuracy is :  {0.9999997287179436}
# At random state {39} : the testing accuracy is :  {0.9999997041094437}
#
# At random state {40} : the training accuracy is :  {0.9999996999209736}
# At random state {40} : the testing accuracy is :  {0.9999997860002585}
#
# At random state {41} : the training accuracy is :  {0.9999997218837858}
# At random state {41} : the testing accuracy is :  {0.9999997699023757}
#
# At random state {42} : the training accuracy is :  {0.9999997463836838}
# At random state {42} : the testing accuracy is :  {0.9999996486372196}
#
# At random state {43} : the training accuracy is :  {0.9999997588783269}
# At random state {43} : the testing accuracy is :  {0.9999995555034169}
#
# At random state {44} : the training accuracy is :  {0.9999997618951462}
# At random state {44} : the testing accuracy is :  {0.9999994160895286}
#
# At random state {45} : the training accuracy is :  {0.9999997419126098}
# At random state {45} : the testing accuracy is :  {0.9999996078076577}
#
# At random state {46} : the training accuracy is :  {0.999999716168645}
# At random state {46} : the testing accuracy is :  {0.9999997686400205}
#
# At random state {47} : the training accuracy is :  {0.9999997293133724}
# At random state {47} : the testing accuracy is :  {0.9999996550349957}
#
# At random state {48} : the training accuracy is :  {0.9999997290546131}
# At random state {48} : the testing accuracy is :  {0.9999997173131343}
#
# At random state {49} : the training accuracy is :  {0.9999997316151439}
# At random state {49} : the testing accuracy is :  {0.9999996227027772}
#
# At random state {50} : the training accuracy is :  {0.9999997697574743}
# At random state {50} : the testing accuracy is :  {0.9999992772160072}
#
# At random state {51} : the training accuracy is :  {0.9999997031612085}
# At random state {51} : the testing accuracy is :  {0.9999997716884683}
#
# At random state {52} : the training accuracy is :  {0.9999997365605264}
# At random state {52} : the testing accuracy is :  {0.9999996652878529}
#
# At random state {53} : the training accuracy is :  {0.9999996996824438}
# At random state {53} : the testing accuracy is :  {0.9999997981728347}
#
# At random state {54} : the training accuracy is :  {0.9999997113527577}
# At random state {54} : the testing accuracy is :  {0.9999997732178443}
#
# At random state {55} : the training accuracy is :  {0.9999997412971674}
# At random state {55} : the testing accuracy is :  {0.9999996348060219}
#
# At random state {56} : the training accuracy is :  {0.9999997345342811}
# At random state {56} : the testing accuracy is :  {0.9999996856069648}
#
# At random state {57} : the training accuracy is :  {0.9999997661729414}
# At random state {57} : the testing accuracy is :  {0.9999994725135471}
#
# At random state {58} : the training accuracy is :  {0.9999997223302276}
# At random state {58} : the testing accuracy is :  {0.9999997410816805}
#
# At random state {59} : the training accuracy is :  {0.9999997436141724}
# At random state {59} : the testing accuracy is :  {0.999999613410011}
#
# At random state {60} : the training accuracy is :  {0.9999997284895433}
# At random state {60} : the testing accuracy is :  {0.9999997135842864}
#
# At random state {61} : the training accuracy is :  {0.9999997295206835}
# At random state {61} : the testing accuracy is :  {0.9999997123597754}
#
# At random state {62} : the training accuracy is :  {0.9999997501995282}
# At random state {62} : the testing accuracy is :  {0.999999536062642}
#
# At random state {63} : the training accuracy is :  {0.9999997080724176}
# At random state {63} : the testing accuracy is :  {0.9999997766563243}
#
# At random state {64} : the training accuracy is :  {0.9999996893649095}
# At random state {64} : the testing accuracy is :  {0.9999998309127711}
#
# At random state {65} : the training accuracy is :  {0.9999997520362377}
# At random state {65} : the testing accuracy is :  {0.9999995554711767}
#
# At random state {66} : the training accuracy is :  {0.9999997345600123}
# At random state {66} : the testing accuracy is :  {0.9999996755025281}
#
# At random state {67} : the training accuracy is :  {0.9999997535976294}
# At random state {67} : the testing accuracy is :  {0.9999995656428385}
#
# At random state {68} : the training accuracy is :  {0.9999997394008812}
# At random state {68} : the testing accuracy is :  {0.9999996539317781}
#
# At random state {69} : the training accuracy is :  {0.9999997362921859}
# At random state {69} : the testing accuracy is :  {0.999999666082516}
#
# At random state {70} : the training accuracy is :  {0.9999997599895902}
# At random state {70} : the testing accuracy is :  {0.9999995220668728}
#
# At random state {71} : the training accuracy is :  {0.999999734338882}
# At random state {71} : the testing accuracy is :  {0.9999996950512217}
#
# At random state {72} : the training accuracy is :  {0.999999736895422}
# At random state {72} : the testing accuracy is :  {0.9999996539685221}
#
# At random state {73} : the training accuracy is :  {0.9999997477676884}
# At random state {73} : the testing accuracy is :  {0.9999996070351094}
#
# At random state {74} : the training accuracy is :  {0.9999997587498227}
# At random state {74} : the testing accuracy is :  {0.9999995625291395}
#
# At random state {75} : the training accuracy is :  {0.9999997221929596}
# At random state {75} : the testing accuracy is :  {0.9999997414349131}
#
# At random state {76} : the training accuracy is :  {0.9999997362861084}
# At random state {76} : the testing accuracy is :  {0.9999996700804974}
#
# At random state {77} : the training accuracy is :  {0.9999997279005823}
# At random state {77} : the testing accuracy is :  {0.9999997049447418}
#
# At random state {78} : the training accuracy is :  {0.9999997362213753}
# At random state {78} : the testing accuracy is :  {0.9999996828355484}
#
# At random state {79} : the training accuracy is :  {0.9999997208422625}
# At random state {79} : the testing accuracy is :  {0.9999997264633056}
#
# At random state {80} : the training accuracy is :  {0.9999997162724997}
# At random state {80} : the testing accuracy is :  {0.9999997580190548}
#
# At random state {81} : the training accuracy is :  {0.999999749981959}
# At random state {81} : the testing accuracy is :  {0.9999996236184675}
#
# At random state {82} : the training accuracy is :  {0.9999997482638906}
# At random state {82} : the testing accuracy is :  {0.9999996193620421}
#
# At random state {83} : the training accuracy is :  {0.9999997503974563}
# At random state {83} : the testing accuracy is :  {0.9999996045894954}
#
# At random state {84} : the training accuracy is :  {0.9999997225406718}
# At random state {84} : the testing accuracy is :  {0.9999997180512666}
#
# At random state {85} : the training accuracy is :  {0.9999997463025123}
# At random state {85} : the testing accuracy is :  {0.9999996100414369}
#
# At random state {86} : the training accuracy is :  {0.9999997741668899}
# At random state {86} : the testing accuracy is :  {0.9999992050337919}
#
# At random state {87} : the training accuracy is :  {0.9999997277440026}
# At random state {87} : the testing accuracy is :  {0.9999997271137551}
#
# At random state {88} : the training accuracy is :  {0.9999997644688232}
# At random state {88} : the testing accuracy is :  {0.9999994664292585}
#
# At random state {89} : the training accuracy is :  {0.9999997467715952}
# At random state {89} : the testing accuracy is :  {0.9999996154250063}
#
# At random state {90} : the training accuracy is :  {0.9999997276165443}
# At random state {90} : the testing accuracy is :  {0.9999997155856005}
#
# At random state {91} : the training accuracy is :  {0.9999997299695014}
# At random state {91} : the testing accuracy is :  {0.9999997117240491}
#
# At random state {92} : the training accuracy is :  {0.9999997121577466}
# At random state {92} : the testing accuracy is :  {0.99999977844944}
#
# At random state {93} : the training accuracy is :  {0.9999997266389442}
# At random state {93} : the testing accuracy is :  {0.9999997176412354}
#
# At random state {94} : the training accuracy is :  {0.9999997387500741}
# At random state {94} : the testing accuracy is :  {0.9999996571126154}
#
# At random state {95} : the training accuracy is :  {0.9999997308853685}
# At random state {95} : the testing accuracy is :  {0.9999997043975036}
#
# At random state {96} : the training accuracy is :  {0.9999997190634843}
# At random state {96} : the testing accuracy is :  {0.999999765919208}
#
# At random state {97} : the training accuracy is :  {0.9999996798824934}
# At random state {97} : the testing accuracy is :  {0.999999831850728}
#
# At random state {98} : the training accuracy is :  {0.9999997180666355}
# At random state {98} : the testing accuracy is :  {0.9999997571131509}
#
# At random state {99} : the training accuracy is :  {0.9999997629885788}
# At random state {99} : the testing accuracy is :  {0.9999994023844317}

# %% [markdown]
# **Overall Conclusion by Linear Regression Algorithm is:**

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=5, test_size=0.20)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print({r2_score(y_test,pred_test)})
# Out:
# {0.9999995804326962}

# %%
print('R2 score is ',r2_score(pred_test,y_test))
print('mean_squared_error', mean_squared_error(pred_test,y_test))
# Out:
# R2 score is  0.9999995805280815
# mean_squared_error 9.497415632935777e-08

# %% [markdown]
# **Here , R2 Score is 99.8 percent , and mean squared error is very very less. Let's try on another algorithms,**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
rf=RandomForestRegressor(n_estimators=10, bootstrap=True, random_state=2000)
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
print('Random_forestregressor result :-')
print('R2 score is :',r2_score(pred,y_test))
print('mean_squared_error :', mean_squared_error(pred,y_test))
# Out:
# Random_forestregressor result :-
# R2 score is : -0.32975194549207143
# mean_squared_error : 0.11230022808209679

# %%
ab = AdaBoostRegressor()
ab.fit(x_train,y_train)
pred=ab.predict(x_test)
print('AdaBoostregressor Result')
print('R2 score is ',r2_score(pred_test,y_test))
print('mean_squared_error', mean_squared_error(pred_test,y_test))
# Out:
# AdaBoostregressor Result
# R2 score is  0.9999995805280815
# mean_squared_error 9.497415632935777e-08

# %% [markdown]
# # Comparing R2 score of different models:

# %%
linear=lr.score(x_train, y_train)
Random=rf.score(x_train,y_train)
Ada=ab.score(x_train,y_train)
print(linear,'\n')
print(Random,'\n')
print(Ada)
# Out:
# 0.9999997489592334
#
# 0.9358347140608675
#
# 0.8544413936492415

# %%
# Let's use Simple Tuning Techniques:

pred_rf= rf.predict(x_test)
from sklearn.model_selection import cross_val_score
lrf= r2_score(y_test,pred_rf)
for j in range(2,10):
    lrfscore=cross_val_score(rf,x,y,cv=j)
    lrfs= lrfscore.mean()
    print('At cv:',j)
    print('cross_validation_score is:',lrfs*100)
    print('R2_score is :',lrf*100)
    print("\n")
# Out:
# At cv: 2
# cross_validation_score is: -145.3195965196163
# R2_score is : 50.38913139432455
#
#
# At cv: 3
# cross_validation_score is: -86.24019564293936
# R2_score is : 50.38913139432455
#
#
# At cv: 4
# cross_validation_score is: -44.59512325587968
# R2_score is : 50.38913139432455
#
#
# At cv: 5
# cross_validation_score is: -76.93997092251126
# R2_score is : 50.38913139432455
#
#
# At cv: 6
# cross_validation_score is: -21.876858487215888
# R2_score is : 50.38913139432455
#
#
# At cv: 7
# cross_validation_score is: -33.50289739798854
# R2_score is : 50.38913139432455
#
#
# At cv: 8
# cross_validation_score is: -48.34651230120815
# R2_score is : 50.38913139432455
#
#
# At cv: 9
# cross_validation_score is: -10.040981940598206
# R2_score is : 50.38913139432455

# %%
# Let's find the cv score by taking the mean. 

lrfscore_selected=cross_val_score(rf,x,y,cv=5).mean()
print("cv score  is:",lrfscore_selected,"\n accuracy_score is:",lrfs)
# Out:
# cv score  is: -0.7693997092251126
#  accuracy_score is: -0.10040981940598205

# %%
# Let's create a DataFrame to compare original and predicted values.

import numpy as np
a =np.array(y_test)
predicted=np.array(rf.predict(x_test))
df=pd.DataFrame({'Orginal':a,'Predicted':predicted}, index=range(len(a)))
df
# Out:
#     Orginal  Predicted
# 0   1.86040   1.760592
# 1   2.11773   2.385048
# 2   2.27513   2.213304
# 3   2.23741   2.280804
# 4   1.68135   1.704417
# 5   2.13090   2.278883
# 6   2.70201   2.276765
# 7   0.65429   1.811212
# 8   2.11569   2.181591
# 9   1.93129   1.872914
# 10  2.43209   2.096190
# 11  1.94939   1.606855
# 12  1.24074   1.672420
# 13  2.51767   2.234961
# 14  2.67585   2.250394
# 15  1.88501   2.433185
# 16  2.05125   2.069251
# 17  0.89991   1.474451
# 18  2.47489   2.231536
# 19  2.53320   2.694636
# 20  1.58782   1.886766
# 21  1.59927   1.554339
# 22  2.02518   2.206395
# 23  1.86399   1.800550
# 24  1.75360   2.043746
# 25  1.95637   2.114128
# 26  2.08528   2.078178
# 27  1.21305   1.597615
# 28  2.32038   2.089353
# 29  1.92313   1.812554
# 30  2.26882   2.282572

# %% [markdown]
# # Conclusion:

# %% [markdown]
# **So ,Here we have predicted the happiness score considering all the other factors mentioned in the dataset.Based on above DataFrame of original and predicted values , we conclude that our predicted values are very much approximate to original values.**
#
# **We have used different models to predict the approximate result , and also used cross validation technique to tune the features.**
